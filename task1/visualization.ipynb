# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df_movies = pd.read_csv('./data/small/movies.csv')
df_movies.head(10)
# Out:
#    movieId                               title
# 0        1                    Toy Story (1995)  \
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
df_movies.tail(10)
# Out:
#       movieId                                              title
# 9732   193565                          Gintama: The Movie (2010)  \
# 9733   193567  anohana: The Flower We Saw That Day - The Movi...
# 9734   193571                                Silver Spoon (2014)
# 9735   193573            Love Live! The School Idol Movie (2015)
# 9736   193579           Jon Stewart Has Left the Building (2015)
# 9737   193581          Black Butler: Book of the Atlantic (2017)
# 9738   193583                       No Game No Life: Zero (2017)
# 9739   193585                                       Flint (2017)
# 9740   193587                Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609                Andrew Dice Clay: Dice Rules (1991)
#
#                                genres
# 9732   Action|Animation|Comedy|Sci-Fi
# 9733                  Animation|Drama
# 9734                     Comedy|Drama
# 9735                        Animation
# 9736                      Documentary
# ...

# %%
df_movies = df_movies.drop(['genres'], axis=1)
df_movies
# Out:
#       movieId                                      title
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
# [9742 rows x 2 columns]

# %%
df_movies.to_csv('outmov.txt', sep='\t', encoding='utf-8', header=False, index_label=False, index=False)

# %%
df_ratings = pd.read_csv('./data/small/ratings.csv')
df_ratings.head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 5       1       70     3.0  964982400
# 6       1      101     5.0  964980868
# 7       1      110     4.0  964982176
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %%
df_ratings['rating'].describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
df_ratings = df_ratings.drop(['timestamp'], axis=1)
df_ratings.head(10)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0
# 5       1       70     3.0
# 6       1      101     5.0
# 7       1      110     4.0
# 8       1      151     5.0
# 9       1      157     5.0

# %%
df_ratings.tail(10)
# Out:
#         userId  movieId  rating
# 100826     610   162350     3.5
# 100827     610   163937     3.5
# 100828     610   163981     3.5
# 100829     610   164179     5.0
# 100830     610   166528     4.0
# 100831     610   166534     4.0
# 100832     610   168248     5.0
# 100833     610   168250     5.0
# 100834     610   168252     5.0
# 100835     610   170875     3.0

# %%
df_ratings.to_csv('out.txt', sep='\t', encoding='utf-8', header=False, index_label=False, index=False)

# %%
df_ratings = df_ratings.sort_values(by=['movieId'], ascending=False)
df_ratings.head(10)
# Out:
#        userId  movieId  rating   timestamp
# 51362     331   193609     4.0  1537157606
# 27259     184   193587     3.5  1537110021
# 27258     184   193585     3.5  1537109805
# 27257     184   193583     3.5  1537109545
# 27256     184   193581     4.0  1537109082
# 27255     184   193579     3.5  1537107259
# 27254     184   193573     4.0  1537099811
# 27253     184   193571     4.0  1537099392
# 27252     184   193567     3.0  1537099103
# 27251     184   193565     3.5  1537098554

# %%
df_links = pd.read_csv('./data/small/links.csv')
df_links.head(10)
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0
# 5        6  113277    949.0
# 6        7  114319  11860.0
# 7        8  112302  45325.0
# 8        9  114576   9091.0
# 9       10  113189    710.0

# %%
df_tags = pd.read_csv('./data/small/tags.csv')
df_tags.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-324771b81a3f> in <module>
# ----> 1 df_tags = pd.read_csv('./data/small/tags.csv')
#       2 df_tags.head(10)
#
# NameError: name 'pd' is not defined

# %%
# Get Genres and plot it 

df['genres'] = df['genres'].str.split('|')
df = df.explode('genres')
count_by_genre = df.groupby('genres')['movieId'].count()

print(count_by_genre)
# Out:
# genres
# (no genres listed)      34
# Action                1828
# Adventure             1263
# Animation              611
# Children               664
# Comedy                3756
# Crime                 1199
# Documentary            440
# Drama                 4361
# Fantasy                779
# Film-Noir               87
# Horror                 978
# IMAX                   158
# Musical                334
# Mystery                573
# Romance               1596
# Sci-Fi                 980
# Thriller              1894
# War                    382
# Western                167
# Name: movieId, dtype: int64

# %%
df
# Out:
#       movieId                                title     genres
# 0           1                     Toy Story (1995)  Adventure
# 0           1                     Toy Story (1995)  Animation
# 0           1                     Toy Story (1995)   Children
# 0           1                     Toy Story (1995)     Comedy
# 0           1                     Toy Story (1995)    Fantasy
# ...       ...                                  ...        ...
# 9738   193583         No Game No Life: Zero (2017)    Fantasy
# 9739   193585                         Flint (2017)      Drama
# 9740   193587  Bungo Stray Dogs: Dead Apple (2018)     Action
# 9740   193587  Bungo Stray Dogs: Dead Apple (2018)  Animation
# 9741   193609  Andrew Dice Clay: Dice Rules (1991)     Comedy
#
# [22084 rows x 3 columns]

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]

plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('Usage')
plt.title('Programming language usage')

plt.show()
